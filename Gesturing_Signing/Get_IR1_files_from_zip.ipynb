# %% [markdown]
# #Get_IR1_files_from_zip.ipynb
# Loads a zip file containing IR1 rep of the .csv data using shared link.
# Original dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/gesture+phase+segmentation) Please follow the original dataset owners citation requests if you use this data in your work.
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
#
# [Lee B. Hinkle](https://userweb.cs.txstate.edu/~lbh31/), Texas State University, [IMICS Lab](https://imics.wp.txstate.edu/)

# %%
import shutil
import pandas as pd

# %%
# !gdown "11OWxTejlTlR53s3RZbSNZdyMdFiN4dZl&confirm=t" # Gesture Phase Raw IR1s in zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11OWxTejlTlR53s3RZbSNZdyMdFiN4dZl&confirm=t
# To: /content/Gesture_Phase_Raw_IR1.zip
# 100% 644k/644k [00:00<00:00, 17.8MB/s]

# %%
my_dir = '.' # change if you want full path or alt dir
shutil.unpack_archive('Gesture_Phase_Raw_IR1.zip', my_dir, 'zip')

# %%
df = pd.read_pickle("a1_raw.pkl")

# %%
df.head()
# Out:
#                               lhx       lhy       lhz       rhx       rhy  \
# datetime
# 1970-01-01 01:35:02.026  5.347435  4.363681  1.501913  5.258967  4.319263
# 1970-01-01 01:35:02.058  4.869622  4.254210  1.556133  5.240113  4.346338
# 1970-01-01 01:35:02.089  5.357447  4.364039  1.500969  5.238928  4.347924
# 1970-01-01 01:35:02.120  4.942886  4.281878  1.546513  5.111436  4.229660
# 1970-01-01 01:35:02.167  5.003160  4.278530  1.542866  4.985812  4.182155
#
#                               rhz        hx        hy        hz        sx  \
# datetime
# 1970-01-01 01:35:02.026  1.488703  5.037871  1.618295  1.778350  5.062803
# 1970-01-01 01:35:02.058  1.554309  5.037610  1.618370  1.778573  5.061430
# 1970-01-01 01:35:02.089  1.554150  5.037514  1.618298  1.778774  5.059245
# 1970-01-01 01:35:02.120  1.527091  5.037526  1.618612  1.778855  5.056475
# 1970-01-01 01:35:02.167  1.520330  5.037557  1.619226  1.778925  5.052367
#
# ...

# %%
df.plot(subplots=True, figsize=(20, 10))
# Out:
# array([<AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>, <AxesSubplot:xlabel='datetime'>,
#        <AxesSubplot:xlabel='datetime'>], dtype=object)
